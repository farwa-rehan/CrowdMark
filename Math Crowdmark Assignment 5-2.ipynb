# %%
import matplotlib.pyplot as plt
import random

# vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# creating function to calculate area of a triangle
def area(x1, y1, x2, y2, x3, y3):
    return abs((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0)

# function to check if a point is inside the triangle
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# starting point
seed = (seed_x, seed_y)

# storing points of the dynamical system
points = [seed]

# prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# making the chaos Game algorithm
for i in range(num_steps):
    # Choose a random vertex
    next_vertex = vertices[random.randint(0, 2)]

    # Get last point
    last_x, last_y = points[-1]
    vx, vy = next_vertex

    # Compute midpoint
    next_point = ((last_x + vx) / 2, (last_y + vy) / 2)

    # Add new point
    points.append(next_point)

# only plot points after the first 12 iterations
points_to_plot = points[12:]

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.show()

# Plot the points
plot_solution(points_to_plot)
# Out:
# Enter the x-coordinate of the seed point:  0
# Enter the y-coordinate of the seed point:  0
# Valid seed point entered.
# Enter the number of steps:  200000
# Number of steps set to 200000.

# %%
import matplotlib.pyplot as plt
import random

# vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# creating function to calculate area of a triangle
def area(x1, y1, x2, y2, x3, y3):
    return abs((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2.0)

# Function to check if a point is inside the triangle
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# starting point
seed = (seed_x, seed_y)

# Store points of the dynamical system
points = [seed]

# prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# chaos Game algorithm
for i in range(num_steps):
    # Choose a random vertex
    next_vertex = vertices[random.randint(0, 2)]

    # Get last point
    last_x, last_y = points[-1]
    vx, vy = next_vertex

    # computing midpoint
    next_point = ((last_x + vx) / 2, (last_y + vy) / 2)

    # adding new point
    points.append(next_point)

# only plotting points after the first 12 iterations
points_to_plot = points[12:]

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.show()

# Plot the points
plot_solution(points_to_plot)
# Out:
# Enter the x-coordinate of the seed point:  1
# Enter the y-coordinate of the seed point:  0
# Valid seed point entered.
# Enter the number of steps:  10000
# Number of steps set to 10000.

# %%
print("Write Up: This assignment consists of creating a simple chaos game with the aim of exploring  a discrete time dynamical systems. The code begins with a seed point that must exist within the parameters of the triagle, the chaos system evolves continuosly through random selection of the triangle's vertices and moving the current point halfway toward that vertex; reultant sequence of points (x, y) coordinates are the solution set to the system. In order to decrease the effect of the initial condition, the plot does not include the first twelve points, as well the initial points for a small number of steps are scattered. However,  after increasing the number of iterations, a triangular structure is quite evident. For many iterations, the solution set approaches a limit known as the Sierpinski Triangle, which is defined as a repetitive fractal. Despite the presence of randomness in the updating rule, the solution set is highly ordered. This represents a further example that simple deterministic rules in combination with random factors or variables can result in complex, yet predictable geometric structures.")
# Out:
# Write Up: This assignment consists of creating a simple chaos game with the aim of exploring  a discrete time dynamical systems. The code begins with a seed point that must exist within the parameters of the triagle, the chaos system evolves continuosly through random selection of the triangle's vertices and moving the current point halfway toward that vertex; reultant sequence of points (x, y) coordinates are the solution set to the system. In order to decrease the effect of the initial condition, the plot does not include the first twelve points, as well the initial points for a small number of steps are scattered. However,  after increasing the number of iterations, a triangular structure is quite evident. For many iterations, the solution set approaches a limit known as the Sierpinski Triangle, which is defined as a repetitive fractal. Despite the presence of randomness in the updating rule, the solution set is highly ordered. This represents a further example that simple determi
# ...
